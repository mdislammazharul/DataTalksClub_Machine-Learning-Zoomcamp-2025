# %% [markdown]
# ### Question 1

# %%
PS D:\OneDrive\OneDrive - stud.tu-darmstadt.de\Others\Course\DataTalksClub\MLZoomCampHW\HW10\machine-learning-zoomcamp\cohorts\2025\05-deployment\homework> python q6_test.py
{'conversion_probability': 0.49999999999842815, 'conversion': False}

# %% [markdown]
# ### Question 2

# %%
PS C:\Users\mazha> .\kind --version
kind version 0.30.0

# %% [markdown]
# ### Question 3

# %%
PS D:\OneDrive\OneDrive - stud.tu-darmstadt.de\Others\Course\DataTalksClub\MLZoomCampHW\HW10> kubectl get nodes
NAME                 STATUS   ROLES           AGE   VERSION
kind-control-plane   Ready    control-plane   63m   v1.34.0
PS D:\OneDrive\OneDrive - stud.tu-darmstadt.de\Others\Course\DataTalksClub\MLZoomCampHW\HW10> kubectl get services
NAME         TYPE        CLUSTER-IP   EXTERNAL-IP   PORT(S)   AGE
kubernetes   ClusterIP   10.96.0.1    <none>        443/TCP   63m

# %% [markdown]
# ### Question 4

# %%
PS D:\OneDrive\OneDrive - stud.tu-darmstadt.de\Others\Course\DataTalksClub\MLZoomCampHW\HW10> kubectl get services
NAME         TYPE        CLUSTER-IP   EXTERNAL-IP   PORT(S)   AGE
kubernetes   ClusterIP   10.96.0.1    <none>        443/TCP   22m

# %% [markdown]
# ### Question 5

# %%
PS C:\Users\mazha> .\kind load docker-image zoomcamp-model:3.13.10-hw10
Image: "zoomcamp-model:3.13.10-hw10" with ID "sha256:6df0ccea057e23ec7265878fcb11ccd65ea70aed67f78147e8a428e6cd41a745" not yet present on node "kind-control-plane", loading...
